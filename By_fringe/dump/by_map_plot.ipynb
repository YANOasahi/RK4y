# %%
import numpy as np
import matplotlib.pyplot as plt

# データの読み込み
data = np.genfromtxt('../by_map.dat')

x_axis = np.array(data[:, 0])
y_axis = np.array(data[:, 1])
z_axis = np.array(data[:, 2])
by = np.array(data[:, 3])

# 3Dスキャッタープロット
box1 = plt.figure(figsize=(14, 6))

# x-y 平面での3Dスキャッター
fig1_1 = box1.add_subplot(1, 3, 1, projection='3d')
fig1_1.scatter(x_axis, y_axis, by, c=by, cmap='viridis', s=10)
fig1_1.set_xlabel('X-axis')
fig1_1.set_ylabel('Y-axis')
fig1_1.set_zlabel('BY')
fig1_1.set_title('X-Y vs BY')

# y-z 平面での3Dスキャッター
fig1_2 = box1.add_subplot(1, 3, 2, projection='3d')
fig1_2.scatter(y_axis, z_axis, by, c=by, cmap='viridis', s=10)
fig1_2.set_xlabel('Y-axis')
fig1_2.set_ylabel('Z-axis')
fig1_2.set_zlabel('BY')
fig1_2.set_title('Y-Z vs BY')

# x-z 平面での3Dスキャッター
fig1_3 = box1.add_subplot(1, 3, 3, projection='3d')
fig1_3.scatter(x_axis, z_axis, by, c=by, cmap='viridis', s=10)
fig1_3.set_xlabel('X-axis')
fig1_3.set_ylabel('Z-axis')
fig1_3.set_zlabel('BY')
fig1_3.set_title('X-Z vs BY')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[4], line 11
#       8 z_axis = np.array(data[:, 2])
#       9 by = np.array(data[:, 3])
# ---> 11 x1, y1 = np.meshgrid(data[:, 0], data[:, 1])
#      12 y2, z2 = np.meshgrid(data[:, 1], data[:, 2])
#      13 x3, z3 = np.meshgrid(data[:, 0], data[:, 2])
#
# File ~/mambaforge/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:5387, in meshgrid(copy, sparse, indexing, *xi)
#    5384     output = np.broadcast_arrays(*output, subok=True)
#    5386 if copy:
# -> 5387     output = tuple(x.copy() for x in output)
#    5389 return output
#
# File ~/mambaforge/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:5387, in <genexpr>(.0)
#    5384     output = np.broadcast_arrays(*output, subok=True)
#    5386 if copy:
# -> 5387     output = tuple(x.copy() for x in output)
#    5389 return output
#
# MemoryError: Unable to allocate 4.43 TiB for an array with shape (780000, 780000) and data type float64

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.genfromtxt('./by_map_z25.dat')

x_axis = np.array(data[:, 0])
y_axis = np.array(data[:, 1])
z_axis = np.array(data[:, 2])
by = np.array(data[:, 3])

fig1 = plt.figure()

box1 = plt.figure(figsize=(14, 6))
fig1_1 = box1.add_subplot(1, 3, 1)
plt.plot(x_axis, by, label='x')
fig1_1 = box1.add_subplot(1, 3, 2)
plt.plot(y_axis, by, label='y')
fig1_1 = box1.add_subplot(1, 3, 3)
plt.plot(z_axis, by, label='z')

plt.legend()
plt.show()
